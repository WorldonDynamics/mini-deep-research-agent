# %%
# Explorafrom utils import load_data

def main():
    df = load_data()
    print("Data loaded successfully:")
    print(df)

if __name__ == "__main__":
    main()
tion Notebook

# This notebook is a starting point for experiments and analysis.
# Add cells to load data from `data/processed/` and run quick EDA.

import pandas as pd
print("Notebook ready — put your experiments here")
